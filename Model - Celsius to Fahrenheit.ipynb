# %%
import tensorflow as tf
import logging

logger = tf.get_logger()
logger.setLevel(logging.ERROR)
import numpy as np

# %%
celsius_q = np.array([-40, -10, 0, 8, 15, 22, 38], dtype=float)
fahrenheit_a = np.array([-40, 14, 32, 46, 59, 72, 100], dtype=float)

for i, c in enumerate(celsius_q):
    print("{} degrees Celsius = {} degrees Fahrenheit".format(c, fahrenheit_a[i]))
# Out:
# -40.0 degrees Celsius = -40.0 degrees Fahrenheit
# -10.0 degrees Celsius = 14.0 degrees Fahrenheit
# 0.0 degrees Celsius = 32.0 degrees Fahrenheit
# 8.0 degrees Celsius = 46.0 degrees Fahrenheit
# 15.0 degrees Celsius = 59.0 degrees Fahrenheit
# 22.0 degrees Celsius = 72.0 degrees Fahrenheit
# 38.0 degrees Celsius = 100.0 degrees Fahrenheit

# %%
l0 = tf.keras.layers.Dense(units=1, input_shape=[1])
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model = tf.keras.Sequential([l0])

# %%
model.compile(loss='mean_squared_error', optimizer=tf.keras.optimizers.Adam(0.1))

# %%
history=model.fit(celsius_q, fahrenheit_a, epochs=500, verbose=False)
print("Finished training the model")
# Out:
# Finished training the model

# %%
import matplotlib.pyplot as plt
plt.xlabel('Epoch Number')
plt.ylabel('Loss Magnitude')
plt.plot(history.history['loss'])

# %%
import numpy as np
X=np.array([24.0], dtype=float)
print(model.predict([X]))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# [[72.38245]]

# %%
print("These are the layer variables: {}".format(l0.get_weights()))
# Out:
# These are the layer variables: [array([[1.8276736]], dtype=float32), array([28.518282], dtype=float32)]

# %%
l0=tf.keras.layers.Dense(units=4, input_shape=[1])
l1=tf.keras.layers.Dense(units=4)
l2=tf.keras.layers.Dense(units=1)
model=tf.keras.Sequential([l0, l1, l2])
model.compile(loss='mean_squared_error', optimizer=tf.keras.optimizers.Adam(0.1))
model.fit(celsius_q, fahrenheit_a, epochs=500, verbose=False)
print("Finished training the model")
import numpy as np
X=np.array([100.0], dtype=float)

print(model.predict([X]))
print("Model predicts that 100 degrees celsius is : {} degree Fahrenheit".format(model.predict([X])))
print("These are the l0 variables: {}".format(l0.get_weights))
print("These are the l1 variables: {}".format(l1.get_weights))
print("These are the l2 variables: {}".format(l2.get_weights))
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Finished training the model
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# [[211.74736]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Model predicts that 100 degrees celsius is : [[211.74736]] degree Fahrenheit
# These are the l0 variables: <bound method Layer.get_weights of <Dense name=dense_5, built=True>>
# These are the l1 variables: <bound method Layer.get_weights of <Dense name=dense_6, built=True>>
# These are the l2 variables: <bound method Layer.get_weights of <Dense name=dense_7, built=True>>
